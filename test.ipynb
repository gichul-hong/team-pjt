# %%
import math 

rec_num = 1

results = [(50 - x, x / 10) for x in range(50, math.ceil(rec_num * 10) - 1, -1)]
print(results)
# Out:
# [(0, 5.0), (1, 4.9), (2, 4.8), (3, 4.7), (4, 4.6), (5, 4.5), (6, 4.4), (7, 4.3), (8, 4.2), (9, 4.1), (10, 4.0), (11, 3.9), (12, 3.8), (13, 3.7), (14, 3.6), (15, 3.5), (16, 3.4), (17, 3.3), (18, 3.2), (19, 3.1), (20, 3.0), (21, 2.9), (22, 2.8), (23, 2.7), (24, 2.6), (25, 2.5), (26, 2.4), (27, 2.3), (28, 2.2), (29, 2.1), (30, 2.0), (31, 1.9), (32, 1.8), (33, 1.7), (34, 1.6), (35, 1.5), (36, 1.4), (37, 1.3), (38, 1.2), (39, 1.1), (40, 1.0)]
